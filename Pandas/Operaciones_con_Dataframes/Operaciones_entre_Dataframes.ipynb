# %% [markdown]
# # Vamos a ver operaciones entre dataframes con Pandas

# %%
import pandas as pd
import numpy as np
from pathlib import Path
data_path = Path('../Estructura_de_Datos/house.csv')

# %%
data = pd.read_csv(data_path, sep=',')
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# Nos quedamos con las primeras 10 filas y las últimas 10
df1 = data.head(10)
df2 = data.tail(10)

# %%
df1
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df2
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4590  2014-07-08 00:00:00  380680.555556       4.0       2.50         2620
# 4591  2014-07-08 00:00:00  396166.666667       3.0       1.75         1880
# 4592  2014-07-08 00:00:00  252980.000000       4.0       2.50         2530
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# 4594  2014-07-09 00:00:00  210614.285714       3.0       2.50         1610
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4590      8331     2.0           0     0          3        2620
# ...

# %%
# Concatenamos ambos dataframes
df = pd.concat([df1, df2], axis = 0) #Le pasamos una lista con los dataframes a concatenar y con axis = 0 le decimos 
# que los una hacia abajo (uno debajo del otro) y con axis = 1 los uniría hacia la derecha (uno al lado del otro)
df.shape
# Out:
# (20, 18)

# %%
# También podemos concatenarlos añadiendole un multiindice:
df = pd.concat([df1, df2], keys = ['first 10 rows', 'last 10 rows'])
df
# Out:
#                                    date         price  bedrooms  bathrooms  \
# first 10 rows 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50
#               1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50
#               2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00
#               3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25
#               4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50
#               5     2014-05-02 00:00:00  4.900000e+05       2.0       1.00
#               6     2014-05-02 00:00:00  3.350000e+05       2.0       2.00
#               7     2014-05-02 00:00:00  4.820000e+05       4.0       2.50
#               8     2014-05-02 00:00:00  4.525000e+05       3.0       2.50
#               9     2014-05-02 00:00:00  6.400000e+05       4.0       2.00
# last 10 rows  4590  2014-07-08 00:00:00  3.806806e+05       4.0       2.50
# ...

# %%
df.loc['first 10 rows'].iloc[-5:] # También podemos acceder a los datos de un multiindice
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 5  2014-05-02 00:00:00  490000.0       2.0        1.0          880      6380
# 6  2014-05-02 00:00:00  335000.0       2.0        2.0         1350      2560
# 7  2014-05-02 00:00:00  482000.0       4.0        2.5         2710     35868
# 8  2014-05-02 00:00:00  452500.0       3.0        2.5         2430     88426
# 9  2014-05-02 00:00:00  640000.0       4.0        2.0         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 5     1.0           0     0          3         880              0      1938
# 6     1.0           0     0          3        1350              0      1976
# 7     2.0           0     0          3        2710              0      1989
# 8     1.0           0     0          4        1570            860      1985
# 9     1.5           0     0          3        1520              0      1945
#
# ...

# %%
# Ahora vamos a unir dataframes con distintas columnas
df1 = data.head(10)[['price', 'bedrooms']]
df2 = data.head(10)[['city', 'statezip', 'country']]
df  = pd.concat([df1, df2], axis = 1)#Lo unimos hacia la derecha
df
# Out:
#        price  bedrooms          city  statezip country
# 0   313000.0       3.0     Shoreline  WA 98133     USA
# 1  2384000.0       5.0       Seattle  WA 98119     USA
# 2   342000.0       3.0          Kent  WA 98042     USA
# 3   420000.0       3.0      Bellevue  WA 98008     USA
# 4   550000.0       4.0       Redmond  WA 98052     USA
# 5   490000.0       2.0       Seattle  WA 98115     USA
# 6   335000.0       2.0       Redmond  WA 98052     USA
# 7   482000.0       4.0  Maple Valley  WA 98038     USA
# 8   452500.0       3.0    North Bend  WA 98045     USA
# 9   640000.0       4.0       Seattle  WA 98115     USA

# %%
df1 = data.head(10)[['city', 'price', 'bedrooms']]
df2 = data.head(10)[['city', 'statezip', 'country']]
df1
# Out:
#            city      price  bedrooms
# 0     Shoreline   313000.0       3.0
# 1       Seattle  2384000.0       5.0
# 2          Kent   342000.0       3.0
# 3      Bellevue   420000.0       3.0
# 4       Redmond   550000.0       4.0
# 5       Seattle   490000.0       2.0
# 6       Redmond   335000.0       2.0
# 7  Maple Valley   482000.0       4.0
# 8    North Bend   452500.0       3.0
# 9       Seattle   640000.0       4.0

# %%
df2
# Out:
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# 5       Seattle  WA 98115     USA
# 6       Redmond  WA 98052     USA
# 7  Maple Valley  WA 98038     USA
# 8    North Bend  WA 98045     USA
# 9       Seattle  WA 98115     USA

# %%
# Vamos a utilizar el merge para unir ambos dataframes
df = df1.merge(df2, how = 'inner', on = 'city')
df
#El metodo merge nos permite unir dos dataframes a partir de una columna en común, en este caso 'city'.
#El argumento how = 'inner' nos indica que solo se queden las filas que tengan un valor en común en la columna 'city'
#El argumento on = 'city' nos indica que la columna en común es 'city'
#Si fuese un left join, se quedarían todas las filas de df1 y solo las filas de df2 que tengan un valor en común en la columna 'city'
#Si fuese un right join, se quedarían todas las filas de df2 y solo las filas de df1 que tengan un valor en común en la columna 'city'
#Si fuese un outer join, se quedarían todas las filas de df1 y df2 que tengan un valor en común en la columna 'city'
#En este caso como todos los valores de city son iguales en ambos dataframes, 
#el resultado es el mismo que con un inner join que con un outer join o con un left join o con un right join
# Out:
#             city      price  bedrooms  statezip country
# 0      Shoreline   313000.0       3.0  WA 98133     USA
# 1        Seattle  2384000.0       5.0  WA 98119     USA
# 2        Seattle  2384000.0       5.0  WA 98115     USA
# 3        Seattle  2384000.0       5.0  WA 98115     USA
# 4           Kent   342000.0       3.0  WA 98042     USA
# 5       Bellevue   420000.0       3.0  WA 98008     USA
# 6        Redmond   550000.0       4.0  WA 98052     USA
# 7        Redmond   550000.0       4.0  WA 98052     USA
# 8        Seattle   490000.0       2.0  WA 98119     USA
# 9        Seattle   490000.0       2.0  WA 98115     USA
# 10       Seattle   490000.0       2.0  WA 98115     USA
# 11       Redmond   335000.0       2.0  WA 98052     USA
# 12       Redmond   335000.0       2.0  WA 98052     USA
# 13  Maple Valley   482000.0       4.0  WA 98038     USA
# 14    North Bend   452500.0       3.0  WA 98045     USA
# 15       Seattle   640000.0       4.0  WA 98119     USA
# ...
